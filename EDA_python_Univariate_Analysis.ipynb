# %% [markdown]
# <a href="https://colab.research.google.com/github/Shruti-2301/EDA/blob/main/EDA_python_Univariate_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-fdea2db6-fc9f-46db-9605-9b108d2b2721" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fdea2db6-fc9f-46db-9605-9b108d2b2721">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("weather_data.csv")

# %%
df.shape
# Out:
# (161, 10)

# %%
df.head()
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0           1   41.0    190.0   7.4     67     5    1  2025    67       S
# 1           2   36.0    118.0   8.0     72     5    2  2025    72       C
# 2           3   12.0    149.0  12.6     74     5    3  2025    74      PS
# 3           4   18.0    313.0  11.5     62     5    4  2025    62       S
# 4           5    NaN      NaN  14.3     56     5    5  2025    56       S

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  161 non-null    int64
#  1   Ozone       123 non-null    float64
#  2   Solar.R     154 non-null    float64
#  3   Wind        161 non-null    float64
#  4   Temp C      161 non-null    object
#  5   Month       161 non-null    object
#  6   Day         161 non-null    int64
#  7   Year        161 non-null    int64
#  8   Temp        161 non-null    int64
#  9   Weather     158 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.7+ KB

# %%
df.size
# Out:
# 1610

# %%
df.describe()
# Out:
#        Unnamed: 0       Ozone     Solar.R        Wind         Day    Year  \
# count  161.000000  123.000000  154.000000  161.000000  161.000000   161.0
# mean    80.391304   41.837398  185.642857    9.903106   15.950311  2025.0
# std     46.121738   32.674343   88.237623    3.503274    9.066285     0.0
# min      1.000000    1.000000    7.000000    1.700000    1.000000  2025.0
# 25%     41.000000   18.000000  121.750000    7.400000    8.000000  2025.0
# 50%     80.000000   31.000000  195.500000    9.700000   16.000000  2025.0
# 75%    120.000000   62.000000  257.500000   11.500000   24.000000  2025.0
# max    158.000000  168.000000  334.000000   20.700000   31.000000  2025.0
#
#              Temp
# count  161.000000
# mean    77.739130
# std      9.397155
# min     56.000000
# 25%     72.000000
# 50%     78.000000
# 75%     84.000000
# max     97.000000

# %%
df.describe(include="object")#Categorical column
# Out:
#        Temp C Month Weather
# count     161   161     158
# unique     41     6       3
# top        81     9       S
# freq       11    35      59

# %%
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2025    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2025    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2025    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2025    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2025    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 156         155   30.0    193.0   6.9     70     9   26  2025    70      PS
# 157         156    NaN    145.0  13.2     77     9   27  2025    77       S
# 158         157   14.0    191.0  14.3     75     9   28  2025    75       S
# 159         158   18.0    131.0   8.0     76     9   29  2025    76       C
# 160         158   18.0    131.0   8.0     76     9   29  2025    76       C
#
# [161 rows x 10 columns]

# %%
df.loc[df.duplicated()]
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 84           70   97.0    272.0   5.7     92     7    9  2025    92       C
# 155         154   41.0    190.0   7.4     67     5    1  2025    67       C
# 160         158   18.0    131.0   8.0     76     9   29  2025    76       C

# %%
df.drop_duplicates()
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2025    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2025    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2025    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2025    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2025    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 154         154   41.0    190.0   7.4     67     5    1  2025    67       C
# 156         155   30.0    193.0   6.9     70     9   26  2025    70      PS
# 157         156    NaN    145.0  13.2     77     9   27  2025    77       S
# 158         157   14.0    191.0  14.3     75     9   28  2025    75       S
# 159         158   18.0    131.0   8.0     76     9   29  2025    76       C
#
# [158 rows x 10 columns]

# %%
df.drop_duplicates(ignore_index=True)
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2025    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2025    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2025    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2025    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2025    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2025    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2025    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2025    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2025    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2025    76       C
#
# [158 rows x 10 columns]

# %%
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2025    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2025    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2025    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2025    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2025    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 156         155   30.0    193.0   6.9     70     9   26  2025    70      PS
# 157         156    NaN    145.0  13.2     77     9   27  2025    77       S
# 158         157   14.0    191.0  14.3     75     9   28  2025    75       S
# 159         158   18.0    131.0   8.0     76     9   29  2025    76       C
# 160         158   18.0    131.0   8.0     76     9   29  2025    76       C
#
# [161 rows x 10 columns]

# %%
#df=df.drop(["Unnamed: 0","Temp C"],axis=1)
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2025    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2025    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2025    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2025    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2025    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 156         155   30.0    193.0   6.9     70     9   26  2025    70      PS
# 157         156    NaN    145.0  13.2     77     9   27  2025    77       S
# 158         157   14.0    191.0  14.3     75     9   28  2025    75       S
# 159         158   18.0    131.0   8.0     76     9   29  2025    76       C
# 160         158   18.0    131.0   8.0     76     9   29  2025    76       C
#
# [161 rows x 10 columns]

# %%
df=df.rename({"Solar.R":"Solar"},axis=1)

# %%
df
# Out:
#      Unnamed: 0  Ozone  Solar  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0  190.0   7.4     67     5    1  2025    67       S
# 1             2   36.0  118.0   8.0     72     5    2  2025    72       C
# 2             3   12.0  149.0  12.6     74     5    3  2025    74      PS
# 3             4   18.0  313.0  11.5     62     5    4  2025    62       S
# 4             5    NaN    NaN  14.3     56     5    5  2025    56       S
# ..          ...    ...    ...   ...    ...   ...  ...   ...   ...     ...
# 156         155   30.0  193.0   6.9     70     9   26  2025    70      PS
# 157         156    NaN  145.0  13.2     77     9   27  2025    77       S
# 158         157   14.0  191.0  14.3     75     9   28  2025    75       S
# 159         158   18.0  131.0   8.0     76     9   29  2025    76       C
# 160         158   18.0  131.0   8.0     76     9   29  2025    76       C
#
# [161 rows x 10 columns]

# %%
df.isna().sum()#for finding null values
# Out:
# Unnamed: 0     0
# Ozone         38
# Solar          7
# Wind           0
# Temp C         0
# Month          0
# Day            0
# Year           0
# Temp           0
# Weather        3
# dtype: int64

# %%
mean=df["Solar"].mean

# %%
df
# Out:
#      Unnamed: 0  Ozone  Solar  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0  190.0   7.4     67     5    1  2025    67       S
# 1             2   36.0  118.0   8.0     72     5    2  2025    72       C
# 2             3   12.0  149.0  12.6     74     5    3  2025    74      PS
# 3             4   18.0  313.0  11.5     62     5    4  2025    62       S
# 4             5    NaN    NaN  14.3     56     5    5  2025    56       S
# ..          ...    ...    ...   ...    ...   ...  ...   ...   ...     ...
# 156         155   30.0  193.0   6.9     70     9   26  2025    70      PS
# 157         156    NaN  145.0  13.2     77     9   27  2025    77       S
# 158         157   14.0  191.0  14.3     75     9   28  2025    75       S
# 159         158   18.0  131.0   8.0     76     9   29  2025    76       C
# 160         158   18.0  131.0   8.0     76     9   29  2025    76       C
#
# [161 rows x 10 columns]

# %%
mean=df["Solar"].mean().round()

# %%
df
# Out:
#      Unnamed: 0  Ozone  Solar  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0  190.0   7.4     67     5    1  2025    67       S
# 1             2   36.0  118.0   8.0     72     5    2  2025    72       C
# 2             3   12.0  149.0  12.6     74     5    3  2025    74      PS
# 3             4   18.0  313.0  11.5     62     5    4  2025    62       S
# 4             5    NaN    NaN  14.3     56     5    5  2025    56       S
# ..          ...    ...    ...   ...    ...   ...  ...   ...   ...     ...
# 156         155   30.0  193.0   6.9     70     9   26  2025    70      PS
# 157         156    NaN  145.0  13.2     77     9   27  2025    77       S
# 158         157   14.0  191.0  14.3     75     9   28  2025    75       S
# 159         158   18.0  131.0   8.0     76     9   29  2025    76       C
# 160         158   18.0  131.0   8.0     76     9   29  2025    76       C
#
# [161 rows x 10 columns]

# %%
mean=df["Solar"].mean().round()
df["Solar"]=df["Solar"].fillna(mean)

# %%
df
# Out:
#      Unnamed: 0  Ozone  Solar  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0  190.0   7.4     67     5    1  2025    67       S
# 1             2   36.0  118.0   8.0     72     5    2  2025    72       C
# 2             3   12.0  149.0  12.6     74     5    3  2025    74      PS
# 3             4   18.0  313.0  11.5     62     5    4  2025    62       S
# 4             5    NaN  186.0  14.3     56     5    5  2025    56       S
# ..          ...    ...    ...   ...    ...   ...  ...   ...   ...     ...
# 156         155   30.0  193.0   6.9     70     9   26  2025    70      PS
# 157         156    NaN  145.0  13.2     77     9   27  2025    77       S
# 158         157   14.0  191.0  14.3     75     9   28  2025    75       S
# 159         158   18.0  131.0   8.0     76     9   29  2025    76       C
# 160         158   18.0  131.0   8.0     76     9   29  2025    76       C
#
# [161 rows x 10 columns]

# %%
df["Month"].unique()
# Out:
# array(['5', 'May', '6', '7', '8', '9'], dtype=object)

# %%
df["Month"].replace({"May":'5'}).unique()
# Out:
# array(['5', '6', '7', '8', '9'], dtype=object)

# %%
df["Month"]=df["Month"].replace({"May":'5'})
df
# Out:
#      Unnamed: 0  Ozone  Solar  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0  190.0   7.4     67     5    1  2025    67       S
# 1             2   36.0  118.0   8.0     72     5    2  2025    72       C
# 2             3   12.0  149.0  12.6     74     5    3  2025    74      PS
# 3             4   18.0  313.0  11.5     62     5    4  2025    62       S
# 4             5    NaN  186.0  14.3     56     5    5  2025    56       S
# ..          ...    ...    ...   ...    ...   ...  ...   ...   ...     ...
# 156         155   30.0  193.0   6.9     70     9   26  2025    70      PS
# 157         156    NaN  145.0  13.2     77     9   27  2025    77       S
# 158         157   14.0  191.0  14.3     75     9   28  2025    75       S
# 159         158   18.0  131.0   8.0     76     9   29  2025    76       C
# 160         158   18.0  131.0   8.0     76     9   29  2025    76       C
#
# [161 rows x 10 columns]

# %%
df["Date"]=pd.to_datetime(df[["Year","Month","Day"]])

# %%
df
# Out:
#      Unnamed: 0  Ozone  Solar  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0  190.0   7.4     67     5    1  2025    67       S
# 1             2   36.0  118.0   8.0     72     5    2  2025    72       C
# 2             3   12.0  149.0  12.6     74     5    3  2025    74      PS
# 3             4   18.0  313.0  11.5     62     5    4  2025    62       S
# 4             5    NaN    NaN  14.3     56     5    5  2025    56       S
# ..          ...    ...    ...   ...    ...   ...  ...   ...   ...     ...
# 156         155   30.0  193.0   6.9     70     9   26  2025    70      PS
# 157         156    NaN  145.0  13.2     77     9   27  2025    77       S
# 158         157   14.0  191.0  14.3     75     9   28  2025    75       S
# 159         158   18.0  131.0   8.0     76     9   29  2025    76       C
# 160         158   18.0  131.0   8.0     76     9   29  2025    76       C
#
# [161 rows x 10 columns]

# %%
df.boxplot("Ozone")
# Out:
# <Axes: >

# %%
df.boxplot("Solar")
# Out:
# <Axes: >

# %%
df.boxplot("Wind")
# Out:
# <Axes: >

# %%
df["Ozone"].describe()
# Out:
# count    123.000000
# mean      41.837398
# std       32.674343
# min        1.000000
# 25%       18.000000
# 50%       31.000000
# 75%       62.000000
# max      168.000000
# Name: Ozone, dtype: float64

# %%
IQR=62-18
maxlimit=62+1.5*IQR
maxlimit
# Out:
# 128.0

# %%
IQR=62-18
minlimit=18-1.5*IQR
minlimit
# Out:
# -48.0

# %%
df[df["Ozone"]>maxlimit]
# Out:
#      Unnamed: 0  Ozone  Solar  Wind Temp C Month  Day  Year  Temp Weather  \
# 61           62  135.0  269.0   4.1     84     7    1  2025    84       S
# 117         117  168.0  238.0   3.4     81     8   25  2025    81      PS
#
#           Date
# 61  2025-07-01
# 117 2025-08-25

# %%
df["Weather"].unique()
# Out:
# array(['S', 'C', 'PS', nan], dtype=object)

# %%
df["Weather"].value_counts()
# Out:
# Weather
# S     59
# C     52
# PS    47
# Name: count, dtype: int64

# %%
df["Weather"].value_counts().plot(kind="bar")
plt.show()

# %%
df["Wind"].value_counts().plot(kind="bar")
plt.show()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Ozone', 'Solar', 'Wind', 'Temp C', 'Month', 'Day',
#        'Year', 'Temp', 'Weather', 'Date'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Unnamed: 0       Ozone       Solar        Wind         Day    Year  \
# count  161.000000  123.000000  161.000000  161.000000  161.000000   161.0
# mean    80.391304   41.837398  185.658385    9.903106   15.950311  2025.0
# min      1.000000    1.000000    7.000000    1.700000    1.000000  2025.0
# 25%     41.000000   18.000000  127.000000    7.400000    8.000000  2025.0
# 50%     80.000000   31.000000  192.000000    9.700000   16.000000  2025.0
# 75%    120.000000   62.000000  255.000000   11.500000   24.000000  2025.0
# max    158.000000  168.000000  334.000000   20.700000   31.000000  2025.0
# std     46.121738   32.674343   86.285870    3.503274    9.066285     0.0
#
#              Temp                           Date
# count  161.000000                            161
# mean    77.739130  2025-07-17 07:18:15.652173824
# min     56.000000            2025-05-01 00:00:00
# 25%     72.000000            2025-06-08 00:00:00
# 50%     78.000000            2025-07-17 00:00:00
# ...

# %%
df.var(numeric_only=True) #to find variance (for numeric values only)
# Out:
# Unnamed: 0    2.127215e+03
# Ozone         1.067613e+03
# Solar         7.445251e+03
# Wind          1.227293e+01
# Day           8.219752e+01
# Year          5.202191e-26
# Temp          8.830652e+01
# dtype: float64

# %%
df.skew(numeric_only=True) #to find skewness negative skewness and positive skewness
# Out:
# Unnamed: 0   -0.000891
# Ozone         1.257618
# Solar        -0.428522
# Wind          0.377375
# Day          -0.029124
# Year          0.000000
# Temp         -0.322533
# dtype: float64

# %%
df["Solar"].plot(kind="hist") #for ploting histogram
plt.show()

# %%
df["Solar"].plot(kind="hist",bins=40)
plt.show()

# %%
df["Wind"].plot(kind="hist",bins=40)
plt.show()

# %%
df["Wind"].plot(kind="kde")
plt.show()

# %%
df["Solar"].plot(kind="kde")
plt.show()

# %%
df.boxplot(column="Ozone")
plt.show()

# %%
df.boxplot(column="Ozone",vert=False)
plt.show()

# %%
sns.displot(data=df,x="Ozone",kind="hist",kde=True)
plt.show()

# %%
sns.displot(data=df,x="Solar",kind="hist",kde=True)
plt.show()

# %%
sns.violinplot(data=df,x="Ozone")
plt.show()

# %%
sns.violinplot(data=df,x="Solar")
plt.show()
