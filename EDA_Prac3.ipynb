# %% [markdown]
# <a href="https://colab.research.google.com/github/Shruti-2301/EDA/blob/main/EDA_Prac3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-0ff58d49-92a6-4bfe-a6a2-b74b728fe2c0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0ff58d49-92a6-4bfe-a6a2-b74b728fe2c0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("patients.csv")

# %%
df.head()
# Out:
#    PatientID   Name    Age  Gender  Weight       Disease
# 0        101   Amit   45.0    Male    72.0      Diabetes
# 1        102  Priya    NaN  Female    65.0  Hypertension
# 2        103  Rahul  120.0    Male    80.0        Asthma
# 3        104   Neha   35.0  Female     NaN      Diabetes
# 4        105  Vikas   52.0    Male    78.0  Hypertension

# %%
df.tail()
# Out:
#     PatientID    Name   Age  Gender  Weight       Disease
# 15        116  Simran   NaN  Female    59.0        Asthma
# 16        117  Deepak  44.0    Male    77.0  Hypertension
# 17        118    Ritu  31.0  Female    56.0         Fever
# 18        119   Arjun  53.0    Male    81.0      Diabetes
# 19        120   Nisha  36.0  Female    63.0        Asthma

# %%
df.shape
# Out:
# (20, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PatientID  20 non-null     int64
#  1   Name       20 non-null     object
#  2   Age        18 non-null     float64
#  3   Gender     20 non-null     object
#  4   Weight     18 non-null     float64
#  5   Disease    20 non-null     object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 1.1+ KB

# %%
df.describe()
# Out:
#        PatientID         Age     Weight
# count   20.00000   18.000000  18.000000
# mean   110.50000   50.111111  68.888889
# std      5.91608   32.363540  11.060735
# min    101.00000   26.000000  54.000000
# 25%    105.75000   33.500000  59.250000
# 50%    110.50000   42.500000  68.500000
# 75%    115.25000   48.500000  77.750000
# max    120.00000  150.000000  90.000000

# %%
df.isnull().sum()
# Out:
# PatientID    0
# Name         0
# Age          2
# Gender       0
# Weight       2
# Disease      0
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())

# %%
df['Weight'] = df['Weight'].fillna(df['Weight'].median())

# %%
df.isnull().sum()
# Out:
# PatientID    0
# Name         0
# Age          0
# Gender       0
# Weight       0
# Disease      0
# dtype: int64

# %%
df.dtypes
# Out:
# PatientID      int64
# Name          object
# Age          float64
# Gender        object
# Weight       float64
# Disease       object
# dtype: object

# %%
df.describe(include="object")
# Out:
#         Name Gender   Disease
# count     20     20        20
# unique    19      2         4
# top     Amit   Male  Diabetes
# freq       2     10         6

# %%
df
# Out:
#     PatientID    Name    Age  Gender  Weight       Disease
# 0         101    Amit   45.0    Male    72.0      Diabetes
# 1         102   Priya    NaN  Female    65.0  Hypertension
# 2         103   Rahul  120.0    Male    80.0        Asthma
# 3         104    Neha   35.0  Female     NaN      Diabetes
# 4         105   Vikas   52.0    Male    78.0  Hypertension
# 5         106   Sneha   28.0  Female    55.0         Fever
# 6         107   Rohan   41.0    Male    82.0      Diabetes
# 7         108   Pooja   33.0  Female    60.0        Asthma
# 8         109   Ankit   47.0    Male    76.0  Hypertension
# 9         110   Kavya   29.0  Female    58.0         Fever
# 10        111    Amit   45.0    Male    72.0      Diabetes
# 11        112   Meera   38.0  Female    62.0        Asthma
# 12        113   Karan  150.0    Male    90.0  Hypertension
# 13        114  Anjali   26.0  Female    54.0         Fever
# 14        115     Raj   49.0    Male     NaN      Diabetes
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
mean_weight = df["Weight"].mean()

# %%
df
# Out:
#     PatientID    Name    Age  Gender  Weight       Disease
# 0         101    Amit   45.0    Male    72.0      Diabetes
# 1         102   Priya    NaN  Female    65.0  Hypertension
# 2         103   Rahul  120.0    Male    80.0        Asthma
# 3         104    Neha   35.0  Female    69.0      Diabetes
# 4         105   Vikas   52.0    Male    78.0  Hypertension
# 5         106   Sneha   28.0  Female    55.0         Fever
# 6         107   Rohan   41.0    Male    82.0      Diabetes
# 7         108   Pooja   33.0  Female    60.0        Asthma
# 8         109   Ankit   47.0    Male    76.0  Hypertension
# 9         110   Kavya   29.0  Female    58.0         Fever
# 10        111    Amit   45.0    Male    72.0      Diabetes
# 11        112   Meera   38.0  Female    62.0        Asthma
# 12        113   Karan  150.0    Male    90.0  Hypertension
# 13        114  Anjali   26.0  Female    54.0         Fever
# 14        115     Raj   49.0    Male    69.0      Diabetes
# ...

# %%
mean_weight = df["Weight"].mean().round()

# %%
df
# Out:
#     PatientID    Name    Age  Gender  Weight       Disease
# 0         101    Amit   45.0    Male    72.0      Diabetes
# 1         102   Priya    NaN  Female    65.0  Hypertension
# 2         103   Rahul  120.0    Male    80.0        Asthma
# 3         104    Neha   35.0  Female    69.0      Diabetes
# 4         105   Vikas   52.0    Male    78.0  Hypertension
# 5         106   Sneha   28.0  Female    55.0         Fever
# 6         107   Rohan   41.0    Male    82.0      Diabetes
# 7         108   Pooja   33.0  Female    60.0        Asthma
# 8         109   Ankit   47.0    Male    76.0  Hypertension
# 9         110   Kavya   29.0  Female    58.0         Fever
# 10        111    Amit   45.0    Male    72.0      Diabetes
# 11        112   Meera   38.0  Female    62.0        Asthma
# 12        113   Karan  150.0    Male    90.0  Hypertension
# 13        114  Anjali   26.0  Female    54.0         Fever
# 14        115     Raj   49.0    Male    69.0      Diabetes
# ...

# %%
mean_weight = df["Weight"].mean().round()
df["Weight"] = df["Weight"].fillna(mean_weight)

# %%
df
# Out:
#     PatientID    Name    Age  Gender  Weight       Disease
# 0         101    Amit   45.0    Male    72.0      Diabetes
# 1         102   Priya    NaN  Female    65.0  Hypertension
# 2         103   Rahul  120.0    Male    80.0        Asthma
# 3         104    Neha   35.0  Female    69.0      Diabetes
# 4         105   Vikas   52.0    Male    78.0  Hypertension
# 5         106   Sneha   28.0  Female    55.0         Fever
# 6         107   Rohan   41.0    Male    82.0      Diabetes
# 7         108   Pooja   33.0  Female    60.0        Asthma
# 8         109   Ankit   47.0    Male    76.0  Hypertension
# 9         110   Kavya   29.0  Female    58.0         Fever
# 10        111    Amit   45.0    Male    72.0      Diabetes
# 11        112   Meera   38.0  Female    62.0        Asthma
# 12        113   Karan  150.0    Male    90.0  Hypertension
# 13        114  Anjali   26.0  Female    54.0         Fever
# 14        115     Raj   49.0    Male    69.0      Diabetes
# ...

# %%
df[(df['Age'] < 0) | (df['Age'] > 100)]
# Out:
#     PatientID   Name    Age Gender  Weight       Disease
# 2         103  Rahul  120.0   Male    80.0        Asthma
# 12        113  Karan  150.0   Male    90.0  Hypertension

# %%
df.loc[(df['Age'] < 0) | (df['Age'] > 100), 'Age'] = np.nan

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())

# %%
df.boxplot("Weight")
# Out:
# <Axes: >

# %%
df.boxplot("Age")
# Out:
# <Axes: >

# %%
df["Age"].describe()
# Out:
# count    20.000000
# mean     40.025000
# std       7.829138
# min      26.000000
# 25%      34.500000
# 50%      41.750000
# 75%      45.000000
# max      53.000000
# Name: Age, dtype: float64

# %%
IQR=45-34.5
maxlimit=45+1.5*IQR
maxlimit
# Out:
# 60.75

# %%
IQR=45-34.5
minlimit=34.5-1.5*IQR
minlimit
# Out:
# 18.75

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['Disease'].unique()
# Out:
# array(['Diabetes', 'Hypertension', 'Asthma', 'Fever'], dtype=object)

# %%
print("Missing Values:")
print(df.isnull().sum())

print("\nDuplicate Records:")
print(df.duplicated().sum())

print("\nFinal Dataset Information:")
df.info()
# Out:
# Missing Values:
# PatientID    0
# Name         0
# Age          0
# Gender       0
# Weight       0
# Disease      0
# dtype: int64
#
# Duplicate Records:
# 0
#
# Final Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PatientID  20 non-null     int64
#  1   Name       20 non-null     object
#  2   Age        20 non-null     float64
#  3   Gender     20 non-null     object
#  4   Weight     20 non-null     float64
#  5   Disease    20 non-null     object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 1.1+ KB

# %%
df
# Out:
#     PatientID    Name    Age  Gender  Weight       Disease
# 0         101    Amit  45.00    Male    72.0      Diabetes
# 1         102   Priya  42.50  Female    65.0  Hypertension
# 2         103   Rahul  41.75    Male    80.0        Asthma
# 3         104    Neha  35.00  Female    69.0      Diabetes
# 4         105   Vikas  52.00    Male    78.0  Hypertension
# 5         106   Sneha  28.00  Female    55.0         Fever
# 6         107   Rohan  41.00    Male    82.0      Diabetes
# 7         108   Pooja  33.00  Female    60.0        Asthma
# 8         109   Ankit  47.00    Male    76.0  Hypertension
# 9         110   Kavya  29.00  Female    58.0         Fever
# 10        111    Amit  45.00    Male    72.0      Diabetes
# 11        112   Meera  38.00  Female    62.0        Asthma
# 12        113   Karan  41.75    Male    90.0  Hypertension
# 13        114  Anjali  26.00  Female    54.0         Fever
# 14        115     Raj  49.00    Male    69.0      Diabetes
# ...

# %%
df["Age"].value_counts().plot(kind="bar")
plt.show()

# %%
df["Weight"].value_counts().plot(kind="bar")
plt.show()

# %%
df["Disease"].value_counts().plot(kind="bar")
plt.show()
